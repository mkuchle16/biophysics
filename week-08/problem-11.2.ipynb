# %% [markdown]
# ## Problem 11.2 Cooperative Binding Data

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
#loading data and creating arrays
data = np.load('hemoglobin.npy')
split = np.hsplit(data,2)
concentration = split[0].flatten()
prob = split[1].flatten()

# %%
plt.plot(concentration,prob)

# %%
c = np.linspace(0,2.5,1001)
k_d = 10
c_bar = c/k_d
n = 1
p = 1/(1+c_bar**n)
plt.figure()
plt.plot(c,p)

# %%
A = np.vstack([prob,np.ones(len(prob))]).T
#B = np.vstack([p,np.ones(len(p))]).T
lst_sq = np.linalg.lstsq(A,c,rcond=None)[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d39c7a623afc> in <module>
# ----> 1 A = np.vstack([prob,np.ones(len(prob))]).T
#       2 #B = np.vstack([p,np.ones(len(p))]).T
#       3 lst_sq = np.linalg.lstsq(A,c,rcond=None)[0]
#
# NameError: name 'np' is not defined

# %%
# Out:
# array([0.9874 , 0.98182, 0.97624, 0.9679 , 0.9568 , 0.9402 , 0.92085,
#        0.90149, 0.8545 , 0.8186 , 0.78   , 0.7358 , 0.6972 , 0.653  ,
#        0.6061 , 0.5565 , 0.5206 , 0.4792 , 0.4378 , 0.4019 , 0.3687 ,
#        0.3411 , 0.3108 , 0.2886 , 0.261  , 0.2416 , 0.2223 , 0.2029 ,
#        0.1863 , 0.1586 , 0.1364 , 0.1142 , 0.0975 , 0.0809 , 0.0725 ,
#        0.064  , 0.0529 , 0.0472 , 0.0416 , 0.0469 , 0.0302 , 0.0329 ,
#        0.0327 , 0.0298 ])
